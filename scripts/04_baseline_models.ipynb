# %%
# Run this in your notebook or as a script
import sys
from pathlib import Path

# Add the src directory to path
sys.path.append(str(Path.cwd() /'src'))

from src.data_utils import DataLoader

# Create the data loader (it will auto-detect paths)
loader = DataLoader()

# Create the master dataset
master_df = loader.create_master_dataset(save=True)

# Get features and target
X, y, feature_cols = loader.get_features_and_target(master_df)

print(f"\n✅ Success!")
print(f"   {len(X)} chemicals ready for modeling")
print(f"   {len(feature_cols)} features")
print(f"   Target distribution:\n{y.value_counts()}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       5 # Add the src directory to path
#       6 sys.path.append(str(Path.cwd() /'src'))
# ----> 8 from src.data_utils import DataLoader
#      10 # Create the data loader (it will auto-detect paths)
#      11 loader = DataLoader()
#
# ModuleNotFoundError: No module named 'src'
